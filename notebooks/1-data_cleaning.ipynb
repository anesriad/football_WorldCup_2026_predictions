# %%
import pandas as pd

df_games = pd.read_csv('/Users/riadanas/football_WorldCup_2026_predictions/data/raw/results_1872_2026.csv')

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
print(df_games.shape)
df_games.head(2)
# Out:
# (49287, 9)
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England         0.0         0.0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland         4.0         2.0   Friendly   London
#
#     country  neutral
# 0  Scotland    False
# 1   England    False

# %%
df_games.tail(2)
# Out:
#              date home_team away_team  home_score  away_score      tournament  \
# 49285  2026-06-27    Panama   England         NaN         NaN  FIFA World Cup
# 49286  2026-06-27   Croatia     Ghana         NaN         NaN  FIFA World Cup
#
#                   city        country  neutral
# 49285  East Rutherford  United States     True
# 49286     Philadelphia  United States     True

# %%
# Split into historical matches and WC2026 fixtures
historical_matches = df_games[df_games['home_score'].notna()].copy()
wc2026_fixtures = df_games[df_games['home_score'].isna()].copy()

# %%
print(historical_matches.shape)
historical_matches.head(1)
# Out:
# (49215, 9)
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England         0.0         0.0   Friendly  Glasgow
#
#     country  neutral
# 0  Scotland    False

# %%
print(wc2026_fixtures.shape)
wc2026_fixtures.head(1)
# Out:
# (72, 9)
#              date home_team     away_team  home_score  away_score  \
# 49215  2026-06-11    Mexico  South Africa         NaN         NaN
#
#            tournament         city country  neutral
# 49215  FIFA World Cup  Mexico City  Mexico    False

# %%
# Save to CSV
historical_matches.to_csv('/Users/riadanas/football_WorldCup_2026_predictions/data/interim/historical_matches.csv', index=False)
wc2026_fixtures.to_csv('/Users/riadanas/football_WorldCup_2026_predictions/data/interim/wc2026_fixtures.csv', index=False)

print(f"Historical matches: {len(historical_matches)}")
print(f"WC2026 fixtures: {len(wc2026_fixtures)}")
# Out:
# Historical matches: 49215
# WC2026 fixtures: 72
